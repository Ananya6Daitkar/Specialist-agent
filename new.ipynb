# %%
# %pip install modal
# Out:
# Requirement already satisfied: modal in /opt/anaconda3/lib/python3.13/site-packages (1.5.0)
# Requirement already satisfied: aiohttp in /opt/anaconda3/lib/python3.13/site-packages (from modal) (3.11.10)
# Requirement already satisfied: cbor2 in /opt/anaconda3/lib/python3.13/site-packages (from modal) (6.1.2)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.13/site-packages (from modal) (2025.10.5)
# Requirement already satisfied: click~=8.1 in /opt/anaconda3/lib/python3.13/site-packages (from modal) (8.3.3)
# Requirement already satisfied: grpclib<0.4.10,>=0.4.7 in /opt/anaconda3/lib/python3.13/site-packages (from modal) (0.4.9)
# Requirement already satisfied: protobuf!=4.24.0,<7.0,>=3.19 in /opt/anaconda3/lib/python3.13/site-packages (from modal) (5.29.3)
# Requirement already satisfied: rich>=12.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from modal) (13.9.4)
# Requirement already satisfied: synchronicity~=0.12.3 in /opt/anaconda3/lib/python3.13/site-packages (from modal) (0.12.3)
# Requirement already satisfied: toml in /opt/anaconda3/lib/python3.13/site-packages (from modal) (0.10.2)
# Requirement already satisfied: types-certifi in /opt/anaconda3/lib/python3.13/site-packages (from modal) (2021.10.8.3)
# Requirement already satisfied: types-toml in /opt/anaconda3/lib/python3.13/site-packages (from modal) (0.10.8.20260518)
# Requirement already satisfied: watchfiles in /opt/anaconda3/lib/python3.13/site-packages (from modal) (1.1.1)
# Requirement already satisfied: typing_extensions~=4.6 in /opt/anaconda3/lib/python3.13/site-packages (from modal) (4.14.1)
# Requirement already satisfied: h2<5,>=3.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from grpclib<0.4.10,>=0.4.7->modal) (4.3.0)
# Requirement already satisfied: multidict in /opt/anaconda3/lib/python3.13/site-packages (from grpclib<0.4.10,>=0.4.7->modal) (6.1.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /opt/anaconda3/lib/python3.13/site-packages (from h2<5,>=3.1.0->grpclib<0.4.10,>=0.4.7->modal) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /opt/anaconda3/lib/python3.13/site-packages (from h2<5,>=3.1.0->grpclib<0.4.10,>=0.4.7->modal) (4.1.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from rich>=12.0.0->modal) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.13/site-packages (from rich>=12.0.0->modal) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->modal) (0.1.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp->modal) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp->modal) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp->modal) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp->modal) (1.5.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp->modal) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/anaconda3/lib/python3.13/site-packages (from aiohttp->modal) (1.18.0)
# Requirement already satisfied: idna>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from yarl<2.0,>=1.17.0->aiohttp->modal) (3.7)
# Requirement already satisfied: anyio>=3.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from watchfiles->modal) (4.13.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !modal token new
# Out:
# The web browser should have opened for you to authenticate and get an API token.
# If it didn't, please copy this URL into your web browser manually:
#
# ]8;id=660811;https://modal.com/token-flow/tf-WRErwIvIoyGF7gdtu2FbhI\https://modal.com/token-flow/tf-WRErwIvIoyGF7gdtu2FbhI]8;;\
#
# ⠋ Waiting for authentication in the web browser
# ⠦ Waiting for token flow to complete...omplete...
# Web authentication finished successfully!
# Token is connected to the ananyapatil8010 workspace.
# Verifying token against https://api.modal.com
# Token verified successfully!
# ⠋ Storing token
# Token written to /Users/nalinee/.modal.toml in profile ananyapatil8010.

# %%
# !modal deploy pricer_service.py
# Out:
# ⠸ Creating objects.....
# └── ⠋ Creating mount /Users/nalinee/Documents/NYAYA/agent/pricer_service.py:
# ⠦ Creating objects...
# └── ⠸ Creating mount /Users/nalinee/Documents/NYAYA/agent/pricer_service.py:
# ⠏ Creating objects...
# └── ⠦ Creating mount /Users/nalinee/Documents/NYAYA/agent/pricer_service.py:
# ⠹ Creating objects...
# ├── 🔨 Created mount /Users/nalinee/Documents/NYAYA/agent/pricer_service.py
# ⠴ Creating objects......
# ├── 🔨 Created mount /Users/nalinee/Documents/NYAYA/agent/pricer_service.py
# ⠏ Creating objects...
# ├── 🔨 Created mount /Users/nalinee/Documents/NYAYA/agent/pricer_service.py
# ⠏ Creating objects...
# ├── 🔨 Created mount /Users/nalinee/Documents/NYAYA/agent/pricer_service.py
# └── 🔨 Created function Pricer.*.
# ✓ Created objects.
# ├── 🔨 Created mount /Users/nalinee/Documents/NYAYA/agent/pricer_service.py
# └── 🔨 Created function Pricer.*.
# ✓ Deployment skipped: no changes detected! ⏭️
#
# View Deployment:
# https://modal.com/apps/ananyapatil8010/main/deployed/pricer-service

# %%
from Specialist_agent import SpecialistAgent

# %%
agent = SpecialistAgent()
# Out:
# [Specialist Agent] Specialist Agent is initializing - connecting to modal

# %%
agent.price("iPhone 16 Pro Max")
# Out:
# [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [Specialist Agent] Specialist Agent completed - predicting $120000.00
# 120000.0

# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /opt/anaconda3/lib/python3.13/site-packages (1.58.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (8.3.3)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: numpy<3,>=1.23 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (2.4.6)
# Requirement already satisfied: packaging>=20 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<4,>=1.4.0 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (11.1.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (0.9.2)
# Requirement already satisfied: protobuf<8,>=3.20 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (5.29.3)
# Requirement already satisfied: pyarrow>=7.0 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (24.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (2.34.2)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (4.14.1)
# Requirement already satisfied: starlette>=0.40.0 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (0.41.3)
# Requirement already satisfied: uvicorn>=0.30.0 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (0.34.0)
# Requirement already satisfied: httptools>=0.6.3 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (0.7.1)
# Requirement already satisfied: anyio>=4.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (4.13.0)
# Requirement already satisfied: python-multipart>=0.0.10 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (0.0.29)
# Requirement already satisfied: websockets>=12.0.0 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (16.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in /opt/anaconda3/lib/python3.13/site-packages (from streamlit) (2.2.0)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.13/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /opt/anaconda3/lib/python3.13/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /opt/anaconda3/lib/python3.13/site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (1.31.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.13/site-packages (from pandas<4,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas<4,>=1.4.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas<4,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/anaconda3/lib/python3.13/site-packages (from requests<3,>=2.27->streamlit) (2025.10.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.13/site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.13/site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas<4,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: h11>=0.8 in /opt/anaconda3/lib/python3.13/site-packages (from uvicorn>=0.30.0->streamlit) (0.16.0)
